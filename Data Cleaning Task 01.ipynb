# %% [markdown]
# # Data Cleaning Task  01

# %% [markdown]
# ## Importing the libaraies

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importing the dataset

# %%
data=pd.read_csv(r"C:\Users\91933\Downloads\train.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
data.shape
# Out:
# (891, 12)

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Name column can never decide survival of a person, hence we can safely delete it
del data["Name"]
data.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
del data["Ticket"]
data.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500   NaN
# 1            2         1       1  female  38.0      1      0  71.2833   C85
# 2            3         1       3  female  26.0      0      0   7.9250   NaN
# 3            4         1       1  female  35.0      1      0  53.1000  C123
# 4            5         0       3    male  35.0      0      0   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
del data["Fare"]
data.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Cabin Embarked
# 0            1         0       3    male  22.0      1      0   NaN        S
# 1            2         1       1  female  38.0      1      0   C85        C
# 2            3         1       3  female  26.0      0      0   NaN        S
# 3            4         1       1  female  35.0      1      0  C123        S
# 4            5         0       3    male  35.0      0      0   NaN        S

# %%
#Name column can never decide survival of a person, hence we can safely delete it
del data["Cabin"]
data.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0            1         0       3    male  22.0      1      0        S
# 1            2         1       1  female  38.0      1      0        C
# 2            3         1       3  female  26.0      0      0        S
# 3            4         1       1  female  35.0      1      0        S
# 4            5         0       3    male  35.0      0      0        S

# %%
# Changing Value for "Male, Female" string values to numeric values , male=1 and female=2
def getNumber(str):
    if str=="male":
        return 1
    else:
        return 2
    
data["Gender"]=data["Sex"].apply(getNumber)
data.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked  Gender
# 0            1         0       3    male  22.0      1      0        S       1
# 1            2         1       1  female  38.0      1      0        C       2
# 2            3         1       3  female  26.0      0      0        S       2
# 3            4         1       1  female  35.0      1      0        S       2
# 4            5         0       3    male  35.0      0      0        S       1

# %%
del data["Sex"]
data.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender
# 0            1         0       3  22.0      1      0        S       1
# 1            2         1       1  38.0      1      0        C       2
# 2            3         1       3  26.0      0      0        S       2
# 3            4         1       1  35.0      1      0        S       2
# 4            5         0       3  35.0      0      0        S       1

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# dtype: int64

# %%
meanS= data[data.SibSp==1].Age.mean()
meanS
# Out:
# 30.089726775956283

# %%
data["age"]=np.where(pd.isnull(data.Age) & data["SibSp"]==1  ,meanS, data["Age"])
data.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender   age
# 0            1         0       3  22.0      1      0        S       1  22.0
# 1            2         1       1  38.0      1      0        C       2  38.0
# 2            3         1       3  26.0      0      0        S       2  26.0
# 3            4         1       1  35.0      1      0        S       2  35.0
# 4            5         0       3  35.0      0      0        S       1  35.0

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# age            147
# dtype: int64

# %%
meanNS=data[data.SibSp==0].Age.mean()
meanNS
# Out:
# 31.39755838641189

# %%
data.age.fillna(meanNS,inplace=True)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender   age
# 0            1         0       3  22.0      1      0        S       1  22.0
# 1            2         1       1  38.0      1      0        C       2  38.0
# 2            3         1       3  26.0      0      0        S       2  26.0
# 3            4         1       1  35.0      1      0        S       2  35.0
# 4            5         0       3  35.0      0      0        S       1  35.0

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# age              0
# dtype: int64

# %%
del data["Age"]
data.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Gender   age
# 0            1         0       3      1      0        S       1  22.0
# 1            2         1       1      1      0        C       2  38.0
# 2            3         1       3      0      0        S       2  26.0
# 3            4         1       1      1      0        S       2  35.0
# 4            5         0       3      0      0        S       1  35.0

# %%
sibSpQ =data[data.Embarked == 'Q'][data.SibSp== 1].shape[0]
sibSpC = data[data.Embarked == 'C'][data.SibSp == 1].shape[0]
sibSpS = data[data.Embarked == 'S'][data.SibSp == 1].shape[0]
print(sibSpQ)
print(sibSpC)
print(sibSpS)
# Out:
# 11
# 53
# 145
# C:\Users\91933\AppData\Local\Temp\ipykernel_16016\79187200.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sibSpQ =data[data.Embarked == 'Q'][data.SibSp== 1].shape[0]
# C:\Users\91933\AppData\Local\Temp\ipykernel_16016\79187200.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sibSpC = data[data.Embarked == 'C'][data.SibSp == 1].shape[0]
# C:\Users\91933\AppData\Local\Temp\ipykernel_16016\79187200.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sibSpS = data[data.Embarked == 'S'][data.SibSp == 1].shape[0]

# %%
sibSpQ =data[data.Embarked == 'Q'][data.SibSp== 0].shape[0]
sibSpC = data[data.Embarked == 'C'][data.SibSp == 0].shape[0]
sibSpS = data[data.Embarked == 'S'][data.SibSp == 0].shape[0]
print(sibSpQ)
print(sibSpC)
print(sibSpS)
# Out:
# 59
# 109
# 438
# C:\Users\91933\AppData\Local\Temp\ipykernel_16016\160472113.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sibSpQ =data[data.Embarked == 'Q'][data.SibSp== 0].shape[0]
# C:\Users\91933\AppData\Local\Temp\ipykernel_16016\160472113.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sibSpC = data[data.Embarked == 'C'][data.SibSp == 0].shape[0]
# C:\Users\91933\AppData\Local\Temp\ipykernel_16016\160472113.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sibSpS = data[data.Embarked == 'S'][data.SibSp == 0].shape[0]

# %%
data.dropna(inplace=True)
data.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Gender   age
# 0            1         0       3      1      0        S       1  22.0
# 1            2         1       1      1      0        C       2  38.0
# 2            3         1       3      0      0        S       2  26.0
# 3            4         1       1      1      0        S       2  35.0
# 4            5         0       3      0      0        S       1  35.0

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# SibSp          0
# Parch          0
# Embarked       0
# Gender         0
# age            0
# dtype: int64

# %%
data.rename(columns={'age':"Age"},inplace=True)
data.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Gender   Age
# 0            1         0       3      1      0        S       1  22.0
# 1            2         1       1      1      0        C       2  38.0
# 2            3         1       3      0      0        S       2  26.0
# 3            4         1       1      1      0        S       2  35.0
# 4            5         0       3      0      0        S       1  35.0

# %%
data.rename(columns={'Gender':"Sex"},inplace=True)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Sex   Age
# 0            1         0       3      1      0        S    1  22.0
# 1            2         1       1      1      0        C    2  38.0
# 2            3         1       3      0      0        S    2  26.0
# 3            4         1       1      1      0        S    2  35.0
# 4            5         0       3      0      0        S    1  35.0

# %%
def getEmb(str):
    if str=="S":
        return 1
    elif str=='Q':
        return 2
    else:
        return 3
data["Embark"]=data["Embarked"].apply(getEmb)
data.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Sex   Age  Embark
# 0            1         0       3      1      0        S    1  22.0       1
# 1            2         1       1      1      0        C    2  38.0       3
# 2            3         1       3      0      0        S    2  26.0       1
# 3            4         1       1      1      0        S    2  35.0       1
# 4            5         0       3      0      0        S    1  35.0       1

# %%
del data['Embarked']
data.rename(columns={'Embark':'Embarked'}, inplace=True)
data.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch  Sex   Age  Embarked
# 0            1         0       3      1      0    1  22.0         1
# 1            2         1       1      1      0    2  38.0         3
# 2            3         1       3      0      0    2  26.0         1
# 3            4         1       1      1      0    2  35.0         1
# 4            5         0       3      0      0    1  35.0         1

# %%
#Drawing a pie chart for number of males and females aboard
from matplotlib import style

males = (data['Sex'] == 1).sum() 
#Summing up all the values of column gender with a 
#condition for male and similary for females
females = (data['Sex'] == 2).sum()
print(males)
print(females)
p = [males, females]
plt.pie(p,    #giving array
       labels = ['Male', 'Female'], #Correspndingly giving labels
       colors = ['green', 'yellow'],   # Corresponding colors
       explode = (0.15, 0),    #How much the gap should me there between the pies
       startangle = 0)  #what start angle should be given
plt.axis('equal') 
plt.show()
# Out:
# 577
# 312

# %%
# More Precise Pie Chart
MaleS=data[data.Sex==1][data.SibSp==1].shape[0]
print(MaleS)
MaleN=data[data.Sex==1][data.SibSp==0].shape[0]
print(MaleN)
FemaleS=data[data.Sex==2][data.SibSp==1].shape[0]
print(FemaleS)
FemaleN=data[data.Sex==2][data.SibSp==0].shape[0]
print(FemaleN)
# Out:
# 103
# 434
# 106
# 172
# C:\Users\91933\AppData\Local\Temp\ipykernel_16016\1530498445.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   MaleS=data[data.Sex==1][data.SibSp==1].shape[0]
# C:\Users\91933\AppData\Local\Temp\ipykernel_16016\1530498445.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   MaleN=data[data.Sex==1][data.SibSp==0].shape[0]
# C:\Users\91933\AppData\Local\Temp\ipykernel_16016\1530498445.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   FemaleS=data[data.Sex==2][data.SibSp==1].shape[0]
# C:\Users\91933\AppData\Local\Temp\ipykernel_16016\1530498445.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   FemaleN=data[data.Sex==2][data.SibSp==0].shape[0]

# %%
chart=[MaleS,MaleN,FemaleS,FemaleN]
colors=['lightskyblue','yellowgreen','Yellow','Orange']
labels=["Survived Male","Not Survived Male","Survived Female","Not Survived Female"]
explode=[0,0.05,0,0.1]
plt.pie(chart,labels=labels,colors=colors,explode=explode,startangle=100,counterclock=False,autopct="%.2f%%")
plt.axis("equal")
plt.show()
